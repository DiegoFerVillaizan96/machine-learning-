# %% [markdown]
# # **Limpieza y visualizacion de datos**
# *  DIEGO FERNANDO VILLAIZAN MELO
# *  MARIA FERNANDA MORA GUERRA
# *  JESUS ANTONIO REYES ACOSTA

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # **Exploración inicial de los  datos**

# %%
# Cargamos los datos
df = pd.read_csv('https://raw.githubusercontent.com/labeconometria/MLxE/main/proyectos1er/dataset_2.csv')
df = df[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender','Dependent_count', 'Education_Level', 'Marital_Status','Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon','Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal','Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt','Total_Trans_Ct']]
df.columns = [columna.lower() for columna in df.columns]

# %%
df.head()
# Out:
#    clientnum     attrition_flag  customer_age gender  dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   education_level marital_status income_category card_category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    months_on_book  total_relationship_count  months_inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.tail()
# Out:
#        clientnum     attrition_flag  customer_age gender  dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       education_level marital_status income_category card_category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        months_on_book  total_relationship_count  months_inactive_12_mon  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   clientnum                 10127 non-null  int64
#  1   attrition_flag            10127 non-null  object
#  2   customer_age              10127 non-null  int64
#  3   gender                    10127 non-null  object
#  4   dependent_count           10127 non-null  int64
#  5   education_level           10127 non-null  object
#  6   marital_status            10127 non-null  object
#  7   income_category           10127 non-null  object
#  8   card_category             10127 non-null  object
#  9   months_on_book            10127 non-null  int64
#  10  total_relationship_count  10127 non-null  int64
#  11  months_inactive_12_mon    10127 non-null  int64
#  12  contacts_count_12_mon     10127 non-null  int64
# ...

# %%
print(f'Numero de datos iniciales : {len(df)}')
df = df.drop_duplicates()  # Se eliminan duplicados explicitos
print(f'Numero de datos despues de ajustar : {len(df)}')
# Out:
# Numero de datos iniciales : 10127
# Numero de datos despues de ajustar : 10127

# %%
for columna in df.columns:   
  print(columna)
  print(df[columna].unique())
  print(' ')
# Out:
# clientnum
# [768805383 818770008 713982108 ... 716506083 717406983 714337233]
#
# attrition_flag
# ['Existing Customer' 'Attrited Customer']
#
# customer_age
# [45 49 51 40 44 32 37 48 42 65 56 35 57 41 61 47 62 54 59 63 53 58 55 66
#  50 38 46 52 39 43 64 68 67 60 73 70 36 34 33 26 31 29 30 28 27]
#
# gender
# ['M' 'F']
#
# dependent_count
# [3 5 4 2 0 1]
#
# education_level
# ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
#
# marital_status
# ['Married' 'Single' 'Unknown' 'Divorced']
#
# income_category
# ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
#
# card_category
# ['Blue' 'Gold' 'Silver' 'Platinum']
#
# months_on_book
# [39 44 36 34 21 46 27 31 54 30 48 37 56 42 49 33 28 38 41 43 45 52 40 50
#  35 47 32 20 29 25 53 24 55 23 22 26 13 51 19 15 17 18 16 14]
#
# total_relationship_count
# [5 6 4 3 2 1]
#
# months_inactive_12_mon
# [1 4 2 3 6 0 5]
#
# contacts_count_12_mon
# [3 2 0 1 4 5 6]
#
# ...

# %%
# Se transforman las variables obect a category
for columna in df.select_dtypes(include='object').columns:   
  df[columna] = df[columna].astype('category')

df['dependent_count'] = df['dependent_count'].astype('category')

# %%
df.describe()
# Out:
#           clientnum  customer_age  months_on_book  total_relationship_count  \
# count  1.012700e+04  10127.000000    10127.000000              10127.000000
# mean   7.391776e+08     46.325960       35.928409                  3.812580
# std    3.690378e+07      8.016814        7.986416                  1.554408
# min    7.080821e+08     26.000000       13.000000                  1.000000
# 25%    7.130368e+08     41.000000       31.000000                  3.000000
# 50%    7.179264e+08     46.000000       36.000000                  4.000000
# 75%    7.731435e+08     52.000000       40.000000                  5.000000
# max    8.283431e+08     73.000000       56.000000                  6.000000
#
#        months_inactive_12_mon  contacts_count_12_mon  credit_limit  \
# count            10127.000000           10127.000000  10127.000000
# mean                 2.341167               2.455317   8631.953698
# std                  1.010622               1.106225   9088.776650
# ...

# %%
df.describe(include='category')
# Out:
#            attrition_flag gender  dependent_count education_level  \
# count               10127  10127            10127           10127
# unique                  2      2                6               7
# top     Existing Customer      F                3        Graduate
# freq                 8500   5358             2732            3128
#
#        marital_status income_category card_category
# count           10127           10127         10127
# unique              4               6             4
# top           Married  Less than $40K          Blue
# freq             4687            3561          9436

# %% [markdown]
# **CONCLUSIONES DE LA LIMPIEZA:**
#
# No encontramos datos duplicados ni explicitos en el primer filtro , tampoco hay datos que falten entonces no se debe ajustar la tabla.
# Igualmente debemos cambiar la variables a categoricas.

# %% [markdown]
# # **Visualizacion de las distribuciones**

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma customer_age',fontsize=16)
sns.histplot(df,x='customer_age',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma months_on_book',fontsize=16)
sns.histplot(df,x='months_on_book',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma credit_limit',fontsize=16)
sns.histplot(df,x='credit_limit',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma total_revolving_bal',fontsize=16)
sns.histplot(df,x='total_revolving_bal',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma avg_open_to_buy',fontsize=16)
sns.histplot(df,x='avg_open_to_buy',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma total_amt_chng_q4_q1',fontsize=16)
sns.histplot(df,x='total_amt_chng_q4_q1',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma total_trans_amt',fontsize=16)
sns.histplot(df,x='total_trans_amt',color='aqua')
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Histograma total_trans_ct',fontsize=16)
sns.histplot(df,x='total_trans_ct',color='aqua')
plt.show()

# %% [markdown]
# # **Conclusiones distribuciones**
#
# Podemos observar que estas sidtribucuiones se asimilan a la informacion encontrada con .describe().
#
# Podemos concluir igualmnete que tienen en algunas distribucion normal con algunos sesgos que se pueden controlar.

# %% [markdown]
# # **VISUALIZACIÓN DE PROPORCIONES**

# %%
df['frecuencia'] = 1
df.describe(include='category')
# Out:
#            attrition_flag gender  dependent_count education_level  \
# count               10127  10127            10127           10127
# unique                  2      2                6               7
# top     Existing Customer      F                3        Graduate
# freq                 8500   5358             2732            3128
#
#        marital_status income_category card_category
# count           10127           10127         10127
# unique              4               6             4
# top           Married  Less than $40K          Blue
# freq             4687            3561          9436

# %%
tabla0 = pd.pivot_table(df,index=['gender'],columns='marital_status',values='frecuencia',aggfunc='sum')
tabla0 = (tabla0/len(df)) * 100
tabla0
# Out:
# marital_status  Divorced    Married     Single   Unknown
# gender
# F               3.969586  24.202627  20.983509  3.752345
# M               3.416609  22.079589  17.952009  3.643725

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Participacion % de los  grupos',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.heatmap(tabla0,annot=True)
plt.show()

# %%
tabla1 = pd.pivot_table(df,index=['gender'],columns='education_level',values='frecuencia',aggfunc='sum')
tabla1 = (tabla1/len(df)) * 100
tabla1
# Out:
# education_level   College  Doctorate   Graduate  High School  Post-Graduate  \
# gender
# F                5.253283   2.537770  16.490570    10.151081       2.597018
# M                4.749679   1.915671  14.397156     9.726474       2.498272
#
# education_level  Uneducated   Unknown
# gender
# F                  7.860176  8.018169
# M                  6.823344  6.981337

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Participacion % de los  grupos',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.heatmap(tabla1,annot=True)
plt.show()

# %%
tabla2 = pd.pivot_table(df,index=['gender'],columns='income_category',values='frecuencia',aggfunc='sum')
tabla2 = (tabla2/len(df)) * 100
tabla2
# Out:
# income_category   $120K +  $40K - $60K  $60K - $80K  $80K - $120K  \
# gender
# F                0.000000    10.012837     0.000000        0.0000
# M                7.178829     7.662684    13.844179       15.1575
#
# income_category  Less than $40K    Unknown
# gender
# F                     32.428162  10.467068
# M                      2.735262   0.513479

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Participacion porcentual por grupos',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.heatmap(tabla2,annot=True)
plt.show()

# %% [markdown]
# # **conclusiones visualizaciones de proporciones**
#
# Podemos detallar que para este trabajo podemos segmentar por ingresos, eduicacion y estado civil, los grupos con mayor presencia porcentual son las mujeres y los hombres casados.
# Cuando relacionamos el genero con la educacion, las mujeres graduadas tienen un mayor porcentaje de participacion, a diferencia de los hombres es un poco menor con un 14%.
# En el tercer grupo se evidencia que los hombres con ingresos de 80k-120ktienen mayor preiencia en la poblacion.

# %% [markdown]
# # **Visualizacion de relaciones**

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Total_trans_amt vs Customer Age',fontsize=16)
sns.scatterplot(y=df['total_trans_amt'],x=df['customer_age'],size=df['card_category'],hue=df['gender'])
plt.ylabel('Total Trans Amt',fontsize=16)
plt.xlabel('Customer Age',fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10,4))
plt.title('Total_trans_amt vs Customer Age',fontsize=16)
sns.scatterplot(y=df['total_trans_amt'],x=df['customer_age'],size=df['card_category'],hue=df['gender'])
plt.ylabel('Total Trans Amt',fontsize=16)
plt.xlabel('Customer Age',fontsize=16)
plt.show()

# %% [markdown]
# **conclusion visualizacion de relaciones**

# %% [markdown]
# No hay alguna relacion lineal entre las variables edad y numero de transacciones, tal vez exista tanta relacion entre estos datos seleccionados, pues igulamente pasa cuando se comparan con la variable month of book

# %% [markdown]
# # **Analisis de correlacion**

# %%
datos = df.select_dtypes(exclude='category').drop(columns=['clientnum','frecuencia'])
fig = plt.figure(figsize=(12,6))
plt.title('Correlación Variables Numericas',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.heatmap(datos.corr(),annot=True)
plt.show()

# %% [markdown]
# # **ANALISIS CORRELACION**
#
# Con este analisis podemos concluir lo que vimos en la seccion anterior, lo cual demuestra que las variables edad y transacciones es negativa, indicando esta una no relacion entre las variables seleccionadas, tendriamos que relaiconar otras para poder tomar mejores decisiones.

# %% [markdown]
# # **Conclusion General**
#
# Podemos visualizar la informacion que tenemos de una manera mas interactiva, podemos tomar conclusiones acorde a las categorizaciones que hayamos establecido, sin embargo podemos llegar a la conclusion de que estas variables tienen muy poca relacion  y que esto afecta el analisis. Igualmente existen variables representativas como genero, nivel educativo o nivel de ingresos que predominan sobre otras variables de los clientes bancarios.
